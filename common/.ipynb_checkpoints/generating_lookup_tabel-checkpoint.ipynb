# %%
import pandas as pd

# %% [markdown]
# # Generating lookup table #

# %%
df_org_data = pd.read_csv('Data.csv')

# %%
df_org_data.head(1)
# Out:
#     Entity Continent  Latitude  Longitude  Average temperature per year  \
# 0  Algeria    Africa     28.03       1.66                            25
#
#    Hospital beds per 1000 people  Medical doctors per 1000 people  GDP/Capita  \
# 0                            1.9                             1.83      4044.3
#
#    Population  Median age  Population aged 65 and over (%)        Date  \
# 0    41318142          29                                6  2019-12-31
#
#    Daily tests  Cases  Deaths
# 0          NaN    0.0     0.0

# %%
df_lookup = df_org_data.copy()

# %%
df_lookup.drop(['Date','Daily tests', 'Deaths', 'Cases'], axis=1, inplace=True)

# %%
df_lookup.set_axis(df_lookup['Entity'], inplace=True)

# %%
df_lookup.rename_axis('Country', inplace=True)
df_lookup.drop(['Entity'], axis=1, inplace=True)

# %%
df_lookup = df_lookup[~df_lookup.index.duplicated(keep='first')]

# %%
df_lookup
# Out:
#                    Continent  Latitude  Longitude  \
# Country
# Algeria               Africa     28.03       1.66
# Argentina      South America    -38.42     -63.62
# Australia            Oceania    -25.27     133.78
# Austria               Europe     47.52      14.55
# Bahrain                 Asia     25.93      50.64
# ...                      ...       ...        ...
# United States  North America     37.09     -95.71
# Uruguay        South America    -32.52     -55.77
# Vietnam                 Asia     14.06     108.28
# Zambia                Africa    -13.13      27.85
# Zimbabwe              Africa    -19.02      29.15
#
#                Average temperature per year  Hospital beds per 1000 people  \
# Country
# Algeria                                  25                           1.90
# Argentina                                14                           5.00
# Australia                                22                           3.84
# Austria                                   8                           7.37
# Bahrain                                  27                           2.00
# ...                                     ...                            ...
# United States                            11                           2.77
# Uruguay                                  16                           2.80
# Vietnam                                  25                           2.60
# Zambia                                   21                           2.00
# Zimbabwe                                 20                           1.70
#
#                Medical doctors per 1000 people  GDP/Capita  Population  \
# Country
# Algeria                                   1.83     4044.30    41318142
# Argentina                                 3.91    18933.91    44271041
# Australia                                 3.50    44648.71    24598933
# Austria                                   5.23    45436.69     8809212
# Bahrain                                   0.92    43290.70     1492584
# ...                                        ...         ...         ...
# United States                             2.57    54225.45   325719178
# Uruguay                                   3.74    20551.41     3456750
# Vietnam                                   0.82     6171.88    95540800
# Zambia                                    0.09     3689.25    17094130
# Zimbabwe                                  0.08     1899.77    16529904
#
#                Median age  Population aged 65 and over (%)
# Country
# Algeria                29                                6
# Argentina              31                               11
# Australia              37                               16
# Austria                44                               19
# Bahrain                32                                2
# ...                   ...                              ...
# United States          38                               16
# Uruguay                35                               15
# Vietnam                32                                7
# Zambia                 17                                2
# Zimbabwe               19                                3
#
# [91 rows x 10 columns]

# %%
df_lookup.to_csv('df_lookup_table.csv')
