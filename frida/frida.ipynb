# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime

# %%
data = pd.read_csv('midlertidig_data.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  Algeria  Argentina  Australia  Austria  Bahrain  Bangladesh  \
# 0  2020-03-01      3.0        NaN       26.0     10.0     41.0         NaN
# 1  2020-03-02      3.0        NaN       29.0     14.0     47.0         NaN
# 2  2020-03-03      NaN        NaN       33.0     18.0      NaN         NaN
# 3  2020-03-04      5.0        1.0       41.0     24.0     49.0         NaN
# 4  2020-03-05     12.0        NaN       52.0     29.0     52.0         NaN
#
#    Belarus  Belgium  Bolivia  ...  Turkey  Uganda  Ukraine  \
# 0      1.0      1.0      NaN  ...     NaN     NaN      NaN
# 1      1.0     19.0      NaN  ...     NaN     NaN      NaN
# 2      NaN     38.0      NaN  ...     NaN     NaN      NaN
# 3      4.0     72.0      NaN  ...     NaN     NaN      1.0
# 4      6.0    125.0      NaN  ...     NaN     NaN      NaN
#
#    United Arab Emirates  United Kingdom  United States  Uruguay  Vietnam  \
# 0                  21.0            42.0           69.0      NaN     16.0
# ...

# %%
data = pd.read_csv('df_lookup_table.csv')
country = data[data['Country'] == 'Algeria']
value = string(country['Population'])
value[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-51af9af72fea> in <module>
#       1 data = pd.read_csv('df_lookup_table.csv')
#       2 country = data[data['Country'] == 'Algeria']
# ----> 3 value = string(country['Population'])
#       4 value[0]
#
# NameError: name 'string' is not defined
