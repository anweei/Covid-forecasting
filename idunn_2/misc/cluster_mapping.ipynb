# %%
#pip install folium <- first time running notebook

# %%
import pandas as pd
from cluster_mapping_func import cluster_mapping_func

# %% [markdown]
# # Mapping of clusters

# %% [markdown]
# This notebook uses clusters created in respectively clustering->clustering_k_means and clustering->clustering_hierarchical that are saved in results->clustering_results to plot all the different clusters on a world map. The notebook uses the function cluster_mapping_func to achieve this. The goal of this mapping is visualizing how the clusters are geographically placed, to supplement the analyses of the achived clusters.

# %% [markdown]
# ## Mapping of k-means clusters

# %%
k_means_1_df = pd.read_parquet('../results/clustering_results/df_kmeans_z_0.parquet')
k_means_2_df = pd.read_parquet('../results/clustering_results/df_kmeans_z_1.parquet')
k_means_3_df = pd.read_parquet('../results/clustering_results/df_kmeans_z_2.parquet')
k_means_4_df = pd.read_parquet('../results/clustering_results/df_kmeans_z_3.parquet')

# %%
k_means_m = cluster_mapping_func(list(k_means_1_df.columns),list(k_means_2_df.columns),list(k_means_3_df.columns),list(k_means_4_df.columns))

# %%
k_means_m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Maping of hierarcical clustters

# %%
hac_1_df = pd.read_parquet('../results/clustering_results/df_hac_z_3.parquet')
hac_2_df = pd.read_parquet('../results/clustering_results/df_hac_z_1.parquet')
hac_3_df = pd.read_parquet('../results/clustering_results/df_hac_z_2.parquet')
hac_4_df = pd.read_parquet('../results/clustering_results/df_hac_z_0.parquet')

# %%
hac_m = cluster_mapping_func(list(hac_1_df.columns),list(hac_2_df.columns),list(hac_3_df.columns),list(hac_4_df.columns))

# %%
hac_m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
