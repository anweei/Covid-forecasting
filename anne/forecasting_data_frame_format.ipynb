# %%
import pandas as pd

# %%
df = pd.read_parquet('../common/covid_cases_ver_2.parquet')

# %%
df.head(3)
# Out:
#             Algeria  Argentina  Australia  Austria  Bangladesh  Belarus  \
# 2020-03-01      3.0        0.0       26.0     10.0         0.0      1.0
# 2020-03-02      3.0        0.0       29.0     14.0         0.0      1.0
# 2020-03-03      3.0        0.0       33.0     18.0         0.0      1.0
#
#             Belgium  Bolivia  Bulgaria  Canada  ...  Turkey  Uganda  Ukraine  \
# 2020-03-01      1.0      0.0       0.0    20.0  ...     0.0     0.0      0.0
# 2020-03-02     19.0      0.0       0.0    24.0  ...     0.0     0.0      0.0
# 2020-03-03     38.0      0.0       0.0    27.0  ...     0.0     0.0      0.0
#
#             United Arab Emirates  United Kingdom  United States  Uruguay  \
# 2020-03-01                  21.0            42.0           69.0      0.0
# 2020-03-02                  21.0            47.0           89.0      0.0
# 2020-03-03                  21.0            69.0          103.0      0.0
#
#             Vietnam  Zambia  Zimbabwe
# 2020-03-01     16.0     0.0       0.0
# 2020-03-02     16.0     0.0       0.0
# 2020-03-03     16.0     0.0       0.0
#
# [3 rows x 89 columns]

# %%
all_countries = list(df.columns)

# %%
df_mod = df.copy()

# %%
for country in all_countries:
    for i in range(1,201):
        df_mod[country][i] = df[country][i] - df[country][i-1]

# %%
df_mod.head(3)
# Out:
#             Algeria  Argentina  Australia  Austria  Bangladesh  Belarus  \
# 2020-03-01      3.0        0.0       26.0     10.0         0.0      1.0
# 2020-03-02      0.0        0.0        3.0      4.0         0.0      0.0
# 2020-03-03      0.0        0.0        4.0      4.0         0.0      0.0
#
#             Belgium  Bolivia  Bulgaria  Canada  ...  Turkey  Uganda  Ukraine  \
# 2020-03-01      1.0      0.0       0.0    20.0  ...     0.0     0.0      0.0
# 2020-03-02     18.0      0.0       0.0     4.0  ...     0.0     0.0      0.0
# 2020-03-03     19.0      0.0       0.0     3.0  ...     0.0     0.0      0.0
#
#             United Arab Emirates  United Kingdom  United States  Uruguay  \
# 2020-03-01                  21.0            42.0           69.0      0.0
# 2020-03-02                   0.0             5.0           20.0      0.0
# 2020-03-03                   0.0            22.0           14.0      0.0
#
#             Vietnam  Zambia  Zimbabwe
# 2020-03-01     16.0     0.0       0.0
# 2020-03-02      0.0     0.0       0.0
# 2020-03-03      0.0     0.0       0.0
#
# [3 rows x 89 columns]

# %%
new_df = pd.DataFrame(columns=['Cases','Country'])

# %%
new_df
# Out:
# Empty DataFrame
# Columns: [Cases, Country]
# Index: []

# %%
for country in all_countries:
    temp_segment = pd.DataFrame(df_mod[country])
    temp_segment.rename(columns={country:"Cases"}, inplace=True)
    temp_segment['Country']=country
    temp_segment['Date'] = temp_segment.index
    new_df = pd.concat([new_df, temp_segment], ignore_index = True)

# %%
new_df
# Out:
#        Cases   Country       Date
# 0        3.0   Algeria 2020-03-01
# 1        0.0   Algeria 2020-03-02
# 2        0.0   Algeria 2020-03-03
# 3        2.0   Algeria 2020-03-04
# 4        7.0   Algeria 2020-03-05
# ...      ...       ...        ...
# 17884   29.0  Zimbabwe 2020-09-13
# 17885   18.0  Zimbabwe 2020-09-14
# 17886    5.0  Zimbabwe 2020-09-15
# 17887   45.0  Zimbabwe 2020-09-16
# 17888   22.0  Zimbabwe 2020-09-17
#
# [17889 rows x 3 columns]

# %%
#new_df.to_parquet('dataframe_cases_per_day.parquet')
