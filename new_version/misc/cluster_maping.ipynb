# %%
#pip install folium <- first time running notebook

# %%
import pandas as pd
from cluster_mapping_func import cluster_mapping_func

# %%
k_means_1_df = pd.read_parquet('../results/clustering_results/df_kmeans_z_0.parquet')
k_means_2_df = pd.read_parquet('../results/clustering_results/df_kmeans_z_1.parquet')
k_means_3_df = pd.read_parquet('../results/clustering_results/df_kmeans_z_2.parquet')
k_means_4_df = pd.read_parquet('../results/clustering_results/df_kmeans_z_3.parquet')

# %%
k_means_1_countries=list(k_means_1_df.columns)
k_means_2_countries=list(k_means_2_df.columns)
k_means_3_countries=list(k_means_3_df.columns)
k_means_4_countries=list(k_means_4_df.columns)

# %%
color_list=['green','red','blue','orange']
i=0
color = color_list[i]
print(color)
# Out:
# green

# %%
m = cluster_mapping_func(k_means_1_countries,k_means_2_countries,k_means_3_countries,k_means_4_countries)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
